# %% [markdown]
# <a href="https://colab.research.google.com/github/paulagpulidog/IntroductionToMachineLearning/blob/main/IML_Chapter2_SupervisedLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Machine Learning with Python
# * by Andreas C. Müller and Sarah Guido
# * 2017
# * Published by O'Reilly
#
# Excercises from the book **Chapter 2 Supervised Learning**. This Chapter gives a brief introduction

# %% [markdown]
# ## Import Libraries

# %%
! pip install mglearn;
import mglearn
import sys
print("Python version: {}".format(sys.version))
import pandas as pd
print("pandas version: {}".format(pd.__version__))
import matplotlib
print("matplotlib version: {}".format(matplotlib.__version__))
import numpy as np
print("NumPy version: {}".format(np.__version__))
import scipy as sp
print("SciPy version: {}".format(sp.__version__))
import IPython
print("IPython version: {}".format(IPython.__version__))
import sklearn
print("scikit-learn version: {}".format(sklearn.__version__))

# %% [markdown]
# ### Sample Data Sets
# *  A synthetic two-class classification dataset is the forge dataset, which has two features
# * The plot has the first feature on the x-axis and the second feature on the y-axis.

# %%
# generate dataset
X, y = mglearn.datasets.make_forge()

# plot dataset
import matplotlib.pyplot as plt
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(["Class 0", "Class 1"], loc=4)
plt.xlabel("First feature")
plt.ylabel("Second feature")
print("X.shape: {}".format(X.shape))
# Out:
# X.shape: (26, 2)
